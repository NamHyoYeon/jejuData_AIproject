# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df1
# Out:
#       Unnamed: 0                일시   도   시군구  관광기후지수 관광기후등급
# 0           1082  2017-01-01 00:00  제주  서귀포시   57.30     보통
# 1           2165  2017-01-01 00:00  제주   제주시   58.59     보통
# 2           2164  2017-01-02 00:00  제주   제주시   33.21     나쁨
# 3           1081  2017-01-02 00:00  제주  서귀포시   37.95     나쁨
# 4           1080  2017-01-03 00:00  제주  서귀포시   62.72     좋음
# ...          ...               ...  ..   ...     ...    ...
# 2161        1085  2019-12-29 00:00  제주   제주시   -0.78     나쁨
# 2162           1  2019-12-30 00:00  제주  서귀포시   -0.38     나쁨
# 2163        1084  2019-12-30 00:00  제주   제주시   -0.40     나쁨
# 2164        1083  2019-12-31 00:00  제주   제주시   -0.94     나쁨
# 2165           0  2019-12-31 00:00  제주  서귀포시   -0.66     나쁨
#
# [2166 rows x 6 columns]

# %%
df1 = pd.read_csv("/content/drive/MyDrive/tensorflow 3조/data/jejuTciGrade.csv")

# %%
df2 = pd.read_excel("/content/drive/MyDrive/tensorflow 3조/data/jejuTourlist.xlsx")

# %%
df1 = df1.iloc[:,1:5]

# %%
df1['일시']=(df1['일시'].str.slice(start=0, stop=10)).str.replace('-','')

# %%
df1
# Out:
#             일시   도   시군구  관광기후지수
# 0     20170101  제주  서귀포시   57.30
# 1     20170101  제주   제주시   58.59
# 2     20170102  제주   제주시   33.21
# 3     20170102  제주  서귀포시   37.95
# 4     20170103  제주  서귀포시   62.72
# ...        ...  ..   ...     ...
# 2161  20191229  제주   제주시   -0.78
# 2162  20191230  제주  서귀포시   -0.38
# 2163  20191230  제주   제주시   -0.40
# 2164  20191231  제주   제주시   -0.94
# 2165  20191231  제주  서귀포시   -0.66
#
# [2166 rows x 4 columns]

# %%
df2
# Out:
#    제주도 관광명소 Unnamed: 1 Unnamed: 2  ...    Unnamed: 10    Unnamed: 11    Unnamed: 12
# 0        순번       관광명소         분류  ...            NaN            NaN            NaN
# 1       NaN        NaN        NaN  ...              금              토              일
# 2         1   넥슨컴퓨터박물관        박물관  ...  10:00 - 18:00  10:00 - 18:00  10:00 - 18:00
# 3         2      이룸갤러리        미술관  ...  10:00 - 21:00  10:00 - 21:00  14:00 - 21:00
# 4         3  오설록 티 뮤지엄        박물관  ...  09:00 - 18:00  09:00 - 18:00  09:00 - 18:00
# ..      ...        ...        ...  ...            ...            ...            ...
# 57       56       모슬포항       자연명소  ...  00:00 - 24:00  00:00 - 24:00  00:00 - 24:00
# 58       57     우도올레보트       자연명소  ...  09:00 - 17:00  09:00 - 17:00  09:00 - 17:00
# 59       58     신창 풍차해         해변  ...  00:00 - 24:00  00:00 - 24:00  00:00 - 24:00
# 60       59     서문공설시장       지역명소  ...  09:00 - 20:00  09:00 - 20:00  09:00 - 20:00
# ...

# %%
df2 = df2.iloc[:,1:13]

# %%
df2
# Out:
#    Unnamed: 1 Unnamed: 2  ...    Unnamed: 11    Unnamed: 12
# 0        관광명소         분류  ...            NaN            NaN
# 1         NaN        NaN  ...              토              일
# 2    넥슨컴퓨터박물관        박물관  ...  10:00 - 18:00  10:00 - 18:00
# 3       이룸갤러리        미술관  ...  10:00 - 21:00  14:00 - 21:00
# 4   오설록 티 뮤지엄        박물관  ...  09:00 - 18:00  09:00 - 18:00
# ..        ...        ...  ...            ...            ...
# 57       모슬포항       자연명소  ...  00:00 - 24:00  00:00 - 24:00
# 58     우도올레보트       자연명소  ...  09:00 - 17:00  09:00 - 17:00
# 59     신창 풍차해         해변  ...  00:00 - 24:00  00:00 - 24:00
# 60     서문공설시장       지역명소  ...  09:00 - 20:00  09:00 - 20:00
# 61       박수기정       지역명소  ...  00:00 - 24:00  00:00 - 24:00
#
# [62 rows x 12 columns]

# %%
df2= df2.iloc[2:,:]

# %%
df2
# Out:
#           Unnamed: 1 Unnamed: 2  ...    Unnamed: 11    Unnamed: 12
# 2           넥슨컴퓨터박물관        박물관  ...  10:00 - 18:00  10:00 - 18:00
# 3              이룸갤러리        미술관  ...  10:00 - 21:00  14:00 - 21:00
# 4          오설록 티 뮤지엄        박물관  ...  09:00 - 18:00  09:00 - 18:00
# 5          제주항공우주박물관        박물관  ...  09:00 - 18:00  09:00 - 18:00
# 6          아르떼뮤지엄 제주        미술관  ...  10:00 - 20:00  10:00 - 20:00
# 7               본태박물        박물관  ...  10:00 - 18:00  10:00 - 18:00
# 8               새별오름         오름  ...  00:00 - 24:00  00:00 - 24:00
# 9      세계자동차&피아노 박물관        박물관  ...  09:00 - 17:30  09:00 - 17:30
# 10                숨도        박물관  ...  08:00 - 18:00  08:00 - 18:00
# 11         건강과 성 박물관        박물관  ...  09:00 - 18:00  09:00 - 18:00
# 12             용머리해안         해변  ...  09:00 - 17:00  09:00 - 17:00
# 13           제주현대미술관        미술관  ...  09:00 - 18:00  09:00 - 18:00
# 14            제주공룡랜드       테마파크  ...  09:30 - 18:00  09:30 - 18:00
# ...

# %%
df2.columns= ['관광명소','분류','구분','도로명주소','지번주소','월','화','수','목','금','토','일']

# %%
df2
# Out:
#                 관광명소    분류  구분  ...              금              토              일
# 2           넥슨컴퓨터박물관   박물관  실내  ...  10:00 - 18:00  10:00 - 18:00  10:00 - 18:00
# 3              이룸갤러리   미술관  실내  ...  10:00 - 21:00  10:00 - 21:00  14:00 - 21:00
# 4          오설록 티 뮤지엄   박물관  실내  ...  09:00 - 18:00  09:00 - 18:00  09:00 - 18:00
# 5          제주항공우주박물관   박물관  실내  ...  09:00 - 18:00  09:00 - 18:00  09:00 - 18:00
# 6          아르떼뮤지엄 제주   미술관  실내  ...  10:00 - 20:00  10:00 - 20:00  10:00 - 20:00
# 7               본태박물   박물관  실내  ...  10:00 - 18:00  10:00 - 18:00  10:00 - 18:00
# 8               새별오름    오름  실외  ...  00:00 - 24:00  00:00 - 24:00  00:00 - 24:00
# 9      세계자동차&피아노 박물관   박물관  실내  ...  09:00 - 17:30  09:00 - 17:30  09:00 - 17:30
# 10                숨도   박물관  실외  ...  08:00 - 18:00  08:00 - 18:00  08:00 - 18:00
# 11         건강과 성 박물관   박물관  실내  ...  09:00 - 18:00  09:00 - 18:00  09:00 - 18:00
# 12             용머리해안    해변  실외  ...  09:00 - 17:00  09:00 - 17:00  09:00 - 17:00
# ...

# %%
df1.to_csv('/content/drive/MyDrive/tensorflow 3조/data/targetData/jejuTciGrade.csv')
df2.to_csv('/content/drive/MyDrive/tensorflow 3조/data/targetData/jejuTourlist.csv')

# %%
df3 = pd.read_csv('/content/drive/MyDrive/tensorflow 3조/data/jejuWeather18.csv', encoding='CP949')

# %%
df3
# Out:
#                 일자  시도명  읍면동명  평균 기온  ...  최대 풍속          업종명       이용금액     데이터기준일자
# 0       2018-01-01  제주시   추자면    5.7  ...    1.8  과실 및 채소 소매업   13569170  2020-12-15
# 1       2018-01-01  제주시  이도1동    2.9  ...    2.4      중식 음식점업   18299000  2020-12-15
# 2       2018-01-01  제주시  이도1동    2.9  ...    2.4  전시 및 행사 대행업     819550  2020-12-15
# 3       2018-01-01  제주시  이도1동    2.9  ...    2.4      일식 음식점업   32160000  2020-12-15
# 4       2018-01-01  제주시  이도1동    2.9  ...    2.4     일반유흥 주점업  199833010  2020-12-15
# ...            ...  ...   ...    ...  ...    ...          ...        ...         ...
# 680372  2018-12-31  제주시   한림읍    1.1  ...    3.7      일식 음식점업   87478900  2020-12-15
# 680373  2018-12-31  제주시   한림읍    1.1  ...    3.7     일반유흥 주점업  177407004  2020-12-15
# 680374  2018-12-31  제주시   한림읍    1.1  ...    3.7       육류 소매업   70761110  2020-12-15
# 680375  2018-12-31  제주시   추자면    3.5  ...    2.0      체인화 편의점   18830360  2020-12-15
# ...

# %%
df4 = pd.read_csv('/content/drive/MyDrive/tensorflow 3조/data/jejuWeather19.csv', encoding='CP949')

# %%
df3['일자'] = df3['일자'].str.replace('-','')

# %%
df4['일자'] = df4['일자'].str.replace('-','')

# %%
df3 = df3.iloc[:,0:6]
df4 = df4.iloc[:,0:6]

# %%
df3
# Out:
#               일자  시도명  읍면동명  평균 기온  일강수량  최대 풍속
# 0       20180101  제주시   추자면    5.7   0.0    1.8
# 1       20180101  제주시  이도1동    2.9   0.0    2.4
# 2       20180101  제주시  이도1동    2.9   0.0    2.4
# 3       20180101  제주시  이도1동    2.9   0.0    2.4
# 4       20180101  제주시  이도1동    2.9   0.0    2.4
# ...          ...  ...   ...    ...   ...    ...
# 680372  20181231  제주시   한림읍    1.1   0.0    3.7
# 680373  20181231  제주시   한림읍    1.1   0.0    3.7
# 680374  20181231  제주시   한림읍    1.1   0.0    3.7
# 680375  20181231  제주시   추자면    3.5   0.0    2.0
# 680376  20181231  제주시   추자면    3.5   0.0    2.0
#
# [680377 rows x 6 columns]

# %%
df4
# Out:
#               일자   시도명 읍면동명  평균 기온  일강수량  최대 풍속
# 0       20190101  서귀포시  대정읍    6.5   0.0   10.0
# 1       20190101  서귀포시  대정읍    6.5   0.0   10.0
# 2       20190101  서귀포시  대정읍    6.5   0.0   10.0
# 3       20190101  서귀포시  대정읍    6.5   0.0   10.0
# 4       20190101  서귀포시  대정읍    6.5   0.0   10.0
# ...          ...   ...  ...    ...   ...    ...
# 694933  20191231  서귀포시  대정읍    4.4   0.0   12.4
# 694934  20191231  서귀포시  대정읍    4.4   0.0   12.4
# 694935  20191231  서귀포시  대정읍    4.4   0.0   12.4
# 694936  20191231  서귀포시  대정읍    4.4   0.0   12.4
# 694937  20191231  서귀포시  대정읍    4.4   0.0   12.4
#
# [694938 rows x 6 columns]

# %%
df3 = df3.drop_duplicates()

# %%
df4 = df4.drop_duplicates()

# %%
df5 = df3.append(df4)

# %%
df5
# Out:
#               일자   시도명  읍면동명  평균 기온  일강수량  최대 풍속
# 0       20180101   제주시   추자면    5.7   0.0    1.8
# 1       20180101   제주시  이도1동    2.9   0.0    2.4
# 24      20180101   제주시  일도2동    2.9   0.0    2.4
# 47      20180101   제주시  이도2동    2.9   0.0    2.4
# 53      20180101   제주시  용담1동    2.9   0.0    2.4
# ...          ...   ...   ...    ...   ...    ...
# 694761  20191231   제주시   아라동   -1.2   0.0    4.1
# 694770  20191231   제주시   구좌읍    2.0   0.0    9.9
# 694809  20191231   제주시   구좌읍    3.4   0.0   11.7
# 694858  20191231  서귀포시   성산읍    1.4   0.0    6.1
# 694905  20191231   제주시   추자면    1.7   0.0    3.1
#
# [48198 rows x 6 columns]

# %%
df5 = df5.sort_values('일자')

# %%
df5
# Out:
#               일자   시도명 읍면동명  평균 기온  일강수량  최대 풍속
# 0       20180101   제주시  추자면    5.7   0.0    1.8
# 944     20180101   제주시  애월읍   -7.6   0.0    3.2
# 947     20180101   제주시  한림읍    3.2   0.0    3.0
# 955     20180101   제주시  한경면    3.2   0.0    3.0
# 991     20180101   제주시  구좌읍    6.2   0.0    5.2
# ...          ...   ...  ...    ...   ...    ...
# 693489  20191231  서귀포시  서홍동    4.3   0.0    1.3
# 693418  20191231   제주시  아라동   -8.5   1.5    1.5
# 693405  20191231   제주시  화북동    0.9   0.0    6.6
# 693633  20191231  서귀포시  중앙동    4.3   0.0    1.3
# 694905  20191231   제주시  추자면    1.7   0.0    3.1
#
# [48198 rows x 6 columns]

# %%
df5.to_csv("/content/drive/MyDrive/tensorflow 3조/data/targetData/jejuWeather18-19.csv")
