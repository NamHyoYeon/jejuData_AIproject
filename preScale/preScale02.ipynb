# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df1 = pd.read_csv("/content/drive/MyDrive/tensorflow 3조/data/targetData/jejuTciGrade.csv")
df2 = pd.read_csv("/content/drive/MyDrive/tensorflow 3조/data/targetData/jejuTourlist.csv")
df3 = pd.read_csv("/content/drive/MyDrive/tensorflow 3조/data/targetData/jejuWeather18-19.csv")

# %%
df1
# Out:
#       Unnamed: 0        일시   도   시군구  관광기후지수
# 0              0  20170101  제주  서귀포시   57.30
# 1              1  20170101  제주   제주시   58.59
# 2              2  20170102  제주   제주시   33.21
# 3              3  20170102  제주  서귀포시   37.95
# 4              4  20170103  제주  서귀포시   62.72
# ...          ...       ...  ..   ...     ...
# 2161        2161  20191229  제주   제주시   -0.78
# 2162        2162  20191230  제주  서귀포시   -0.38
# 2163        2163  20191230  제주   제주시   -0.40
# 2164        2164  20191231  제주   제주시   -0.94
# 2165        2165  20191231  제주  서귀포시   -0.66
#
# [2166 rows x 5 columns]

# %%
df2
# Out:
#     Unnamed: 0              관광명소  ...              토              일
# 0            2          넥슨컴퓨터박물관  ...  10:00 - 18:00  10:00 - 18:00
# 1            3             이룸갤러리  ...  10:00 - 21:00  14:00 - 21:00
# 2            4         오설록 티 뮤지엄  ...  09:00 - 18:00  09:00 - 18:00
# 3            5         제주항공우주박물관  ...  09:00 - 18:00  09:00 - 18:00
# 4            6         아르떼뮤지엄 제주  ...  10:00 - 20:00  10:00 - 20:00
# 5            7              본태박물  ...  10:00 - 18:00  10:00 - 18:00
# 6            8              새별오름  ...  00:00 - 24:00  00:00 - 24:00
# 7            9     세계자동차&피아노 박물관  ...  09:00 - 17:30  09:00 - 17:30
# 8           10                숨도  ...  08:00 - 18:00  08:00 - 18:00
# 9           11         건강과 성 박물관  ...  09:00 - 18:00  09:00 - 18:00
# 10          12             용머리해안  ...  09:00 - 17:00  09:00 - 17:00
# 11          13           제주현대미술관  ...  09:00 - 18:00  09:00 - 18:00
# 12          14            제주공룡랜드  ...  09:30 - 18:00  09:30 - 18:00
# ...

# %%
df3
# Out:
#        Unnamed: 0        일자   시도명 읍면동명  평균 기온  일강수량  최대 풍속
# 0               0  20180101   제주시  추자면    5.7   0.0    1.8
# 1             944  20180101   제주시  애월읍   -7.6   0.0    3.2
# 2             947  20180101   제주시  한림읍    3.2   0.0    3.0
# 3             955  20180101   제주시  한경면    3.2   0.0    3.0
# 4             991  20180101   제주시  구좌읍    6.2   0.0    5.2
# ...           ...       ...   ...  ...    ...   ...    ...
# 48193      693489  20191231  서귀포시  서홍동    4.3   0.0    1.3
# 48194      693418  20191231   제주시  아라동   -8.5   1.5    1.5
# 48195      693405  20191231   제주시  화북동    0.9   0.0    6.6
# 48196      693633  20191231  서귀포시  중앙동    4.3   0.0    1.3
# 48197      694905  20191231   제주시  추자면    1.7   0.0    3.1
#
# [48198 rows x 7 columns]

# %%
df3[df3['일자']==20180101]
# Out:
#     Unnamed: 0        일자   시도명 읍면동명  평균 기온  일강수량  최대 풍속
# 0            0  20180101   제주시  추자면    5.7   0.0    1.8
# 1          944  20180101   제주시  애월읍   -7.6   0.0    3.2
# 2          947  20180101   제주시  한림읍    3.2   0.0    3.0
# 3          955  20180101   제주시  한경면    3.2   0.0    3.0
# 4          991  20180101   제주시  구좌읍    6.2   0.0    5.2
# ..         ...       ...   ...  ...    ...   ...    ...
# 62         472  20180101   제주시  외도동    5.0   0.0    2.5
# 63         442  20180101  서귀포시  중문동   -2.7   0.0    3.2
# 64         425  20180101  서귀포시  대륜동    4.9   0.0    1.9
# 65         401  20180101  서귀포시  대정읍    6.8   0.0    6.9
# 66         567  20180101  서귀포시  천지동    4.9   0.0    1.9
#
# [67 rows x 7 columns]

# %%
import datetime
days = ['월','화','수','목','금','토','일']

# %%
pd.to_datetime(df3['일자'], infer_datetime_format=True)
# Out:
# 0       1970-01-01 00:00:00.020180101
# 1       1970-01-01 00:00:00.020180101
# 2       1970-01-01 00:00:00.020180101
# 3       1970-01-01 00:00:00.020180101
# 4       1970-01-01 00:00:00.020180101
#                      ...
# 48193   1970-01-01 00:00:00.020191231
# 48194   1970-01-01 00:00:00.020191231
# 48195   1970-01-01 00:00:00.020191231
# 48196   1970-01-01 00:00:00.020191231
# 48197   1970-01-01 00:00:00.020191231
# Name: 일자, Length: 48198, dtype: datetime64[ns]
