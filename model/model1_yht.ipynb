# %% [markdown]
# 데이터분석

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/tensorflow 3조/data/targetData/modelFeature_01.csv")
df
# Out:
#        Unnamed: 0          날짜   시군구  읍면동  내국인방문자수  ...  평균기온  일강수량  최대풍속   월  요일
# 0               0  2017-01-01  서귀포시  남원읍   201792  ...   0.0   0.0   0.0   1   6
# 1               1  2017-01-01  서귀포시  대륜동   168298  ...   0.0   0.0   0.0   1   6
# 2               2  2017-01-01  서귀포시  대정읍   139549  ...   0.0   0.0   0.0   1   6
# 3               3  2017-01-01  서귀포시  대천동   133527  ...   0.0   0.0   0.0   1   6
# 4               4  2017-01-01  서귀포시  동홍동   153245  ...   0.0   0.0   0.0   1   6
# ...           ...         ...   ...  ...      ...  ...   ...   ...   ...  ..  ..
# 47080       47080  2019-12-31   제주시  조천읍   299736  ...   0.9   0.0   7.6  12   1
# 47081       47081  2019-12-31   제주시  추자면    24093  ...   1.7   0.0   3.1  12   1
# 47082       47082  2019-12-31   제주시  한경면    68930  ...   2.3   0.0   7.2  12   1
# 47083       47083  2019-12-31   제주시  한림읍   197290  ...   2.3   0.0   7.2  12   1
# 47084       47084  2019-12-31   제주시  화북동   246814  ...   0.9   0.0   7.6  12   1
#
# ...

# %% [markdown]
# folium

# %%
import folium

# %%
df2 = pd.read_csv("/content/drive/MyDrive/tensorflow 3조/data/targetData/jejuTourlist.csv")
df2
# Out:
#     Unnamed: 0              관광명소  ...              토              일
# 0            2          넥슨컴퓨터박물관  ...  10:00 - 18:00  10:00 - 18:00
# 1            3             이룸갤러리  ...  10:00 - 21:00  14:00 - 21:00
# 2            4         오설록 티 뮤지엄  ...  09:00 - 18:00  09:00 - 18:00
# 3            5         제주항공우주박물관  ...  09:00 - 18:00  09:00 - 18:00
# 4            6         아르떼뮤지엄 제주  ...  10:00 - 20:00  10:00 - 20:00
# 5            7             본태박물관  ...  10:00 - 18:00  10:00 - 18:00
# 6            8              새별오름  ...  00:00 - 24:00  00:00 - 24:00
# 7            9     세계자동차&피아노 박물관  ...  09:00 - 17:30  09:00 - 17:30
# 8           10                숨도  ...  08:00 - 18:00  08:00 - 18:00
# 9           11         건강과 성 박물관  ...  09:00 - 18:00  09:00 - 18:00
# 10          12             용머리해안  ...  09:00 - 17:00  09:00 - 17:00
# 11          13           제주현대미술관  ...  09:00 - 18:00  09:00 - 18:00
# 12          14            제주공룡랜드  ...  09:30 - 18:00  09:30 - 18:00
# ...

# %%
map = folium.Map(location = [33.371058,126.570421], zoom_start =11)

# %%
folium.Marker([33.236183,126.359575], popup = '박수기정', tooltip='박수기정', icon =folium.Icon(icon = 'car', prefix='fa', color = 'red')).add_to(map)
folium.Marker([33.424339,126.931099], popup = '섭지코지', tooltip='섭지코지', icon =folium.Icon(icon = 'car', prefix='fa', color = 'orange')).add_to(map)
folium.Marker([33.358016,126.462433], popup = '1100고지', tooltip='1100고지', icon =folium.Icon(icon = 'car', prefix='fa', color = 'blue')).add_to(map)
folium.Marker([33.232035,126.314641], popup = '용머리해안', tooltip='용머리해안', icon =folium.Icon(icon = 'car', prefix='fa', color = 'green')).add_to(map)
folium.Marker([33.371058,126.570421], popup = '사라오름', tooltip='사라오름', icon =folium.Icon(icon = 'car', prefix='fa', color = 'pink')).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...
